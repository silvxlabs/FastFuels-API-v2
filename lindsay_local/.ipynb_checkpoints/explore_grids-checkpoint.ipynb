# %% [markdown]
# # Griddle Exploration
# Load the Blue Mountain test domain and build datasets for manual investigation.

# %%
import json
import sys

import geopandas as gpd
import matplotlib.pyplot as plt
import numpy as np
import rioxarray  # noqa: F401 — activates .rio accessor
import xarray as xr

# Adjust these to match your local layout
DOMAIN_FILE = "../tests/data/domains/blue_mtn.json"
GRIDDLE_SRC = "../"  # so `griddle` and `lib` packages are importable
sys.path.insert(0, GRIDDLE_SRC)

# %%
# --- Domain ---------------------------------------------------------------
with open(DOMAIN_FILE) as f:
    domain = json.load(f)

crs = domain["crs"]["properties"]["name"]
roi = gpd.GeoDataFrame.from_features(domain["features"], crs=crs)

print("CRS  :", roi.crs)
print("Bounds:", roi.total_bounds)
roi.plot()
plt.title("Blue Mountain domain")
plt.show()

# %%
# --- Handlers (import what you need) --------------------------------------
from griddle.handlers.landfire import fetch_fbfm40, fetch_topography
from griddle.summarize import summarize_dataset

# %%
# --- Example: fetch FBFM40 (categorical) ----------------------------------
ds_fbfm = fetch_fbfm40(roi=roi, version="2024", extent_buffer_cells=8)
ds_fbfm

# %%
# --- Example: fetch topography (continuous, multi-band) -------------------
from unittest.mock import MagicMock
progress = MagicMock()  # stub — topography handler requires a progress callback

ds_topo = fetch_topography(
    roi=roi,
    version="2020",
    bands=["elevation", "slope", "aspect"],
    progress=progress,
    extent_buffer_cells=8,
)
ds_topo
